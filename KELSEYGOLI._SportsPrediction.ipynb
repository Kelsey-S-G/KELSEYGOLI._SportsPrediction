# %% [markdown]
# Data Preparation and Feature Extraction

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

players = pd.read_csv('players_22.csv')
male_legacy = pd.read_csv('male_players (legacy).csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2100\2734045164.py:5: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv('players_22.csv')
# C:\Users\User\AppData\Local\Temp\ipykernel_2100\2734045164.py:6: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   male_legacy = pd.read_csv('male_players (legacy).csv')

# %%
male_legacy
# Out:
#         player_id                                        player_url  \
# 0          158023                /player/158023/lionel-messi/150002
# 1           20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2            9014                  /player/9014/arjen-robben/150002
# 3           41236           /player/41236/zlatan-ibrahimovic/150002
# 4          167495                /player/167495/manuel-neuer/150002
# ...           ...                                               ...
# 161578     269011                   /player/269011/ziye-zhao/230002
# 161579     269019                   /player/269019/junjie-wu/230002
# 161580     271093               /player/271093/kailin-barlow/230002
# 161581     271555               /player/271555/gideon-tetteh/230002
# 161582     271608           /player/271608/aqeel-al-dhafeeri/230002
#
#         fifa_version  fifa_update fifa_update_date         short_name  \
# 0                 15            2       2014-09-18           L. Messi
# 1                 15            2       2014-09-18  Cristiano Ronaldo
# 2                 15            2       2014-09-18          A. Robben
# 3                 15            2       2014-09-18     Z. Ibrahimović
# 4                 15            2       2014-09-18           M. Neuer
# ...              ...          ...              ...                ...
# 161578            23            2       2022-09-26          Zhao Ziye
# 161579            23            2       2022-09-26          Wu Junjie
# 161580            23            2       2022-09-26          K. Barlow
# 161581            23            2       2022-09-26          G. Tetteh
# 161582            23            2       2022-09-26     A. Al Dhafeeri
#
#                                   long_name player_positions  overall  \
# 0            Lionel Andrés Messi Cuccittini               CF       93
# 1       Cristiano Ronaldo dos Santos Aveiro           LW, LM       92
# 2                              Arjen Robben       RM, LM, RW       90
# 3                        Zlatan Ibrahimović               ST       90
# 4                        Manuel Peter Neuer               GK       90
# ...                                     ...              ...      ...
# 161578                                  赵梓业               RW       46
# 161579                                  吴俊杰               LB       46
# 161580                        Kailin Barlow              CDM       46
# 161581                        Gideon Tetteh           RW, LW       46
# 161582                    Aqeel Al Dhafeeri               CB       46
#
#         potential  ...   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 0              95  ...  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3  15+3
# 1              92  ...  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3  16+3
# 2              90  ...  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3  14+3
# 3              90  ...  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3  17+3
# 4              90  ...  40+3  40+3  36+3  36+3  38+3  38+3  38+3  36+3  87+3
# ...           ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 161578         61  ...  32+2  32+2  37+2  36+2  31+2  31+2  31+2  36+2  14+2
# 161579         58  ...  41+2  41+2  43+2  44+2  48+2  48+2  48+2  44+2  15+2
# 161580         58  ...  45+2  45+2  47+2  47+2  46+2  46+2  46+2  47+2  14+2
# 161581         70  ...  30+2  30+2  34+2  32+2  28+2  28+2  28+2  32+2  15+2
# 161582         63  ...  40+2  40+2  39+2  41+2  46+2  46+2  46+2  41+2  13+2
#
#                                           player_face_url
# 0       https://cdn.sofifa.net/players/158/023/15_120.png
# 1       https://cdn.sofifa.net/players/020/801/15_120.png
# 2       https://cdn.sofifa.net/players/009/014/15_120.png
# 3       https://cdn.sofifa.net/players/041/236/15_120.png
# 4       https://cdn.sofifa.net/players/167/495/15_120.png
# ...                                                   ...
# 161578  https://cdn.sofifa.net/players/269/011/23_120.png
# 161579  https://cdn.sofifa.net/players/269/019/23_120.png
# 161580  https://cdn.sofifa.net/players/271/093/23_120.png
# 161581  https://cdn.sofifa.net/players/271/555/23_120.png
# 161582  https://cdn.sofifa.net/players/271/608/23_120.png
#
# [161583 rows x 110 columns]

# %%
male_legacy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161583 entries, 0 to 161582
# Columns: 110 entries, player_id to player_face_url
# dtypes: float64(18), int64(45), object(47)
# memory usage: 135.6+ MB

# %%
legacy_columns = set(male_legacy.columns)
players_22_columns = set(players.columns)

columns_to_drop = legacy_columns - players_22_columns

male_legacy = male_legacy.drop(columns=columns_to_drop)

# %%
L = []
L_less = []
for i in male_legacy.columns:
    if(male_legacy[i].isnull().sum())<(0.4*(male_legacy.shape[0])):
        L.append(i)
    else:
        L_less.append(i)

# %%
male_legacy = male_legacy[L]

# %%
numeric_data = male_legacy.select_dtypes(include=np.number)
non_numeric = male_legacy.select_dtypes(include=['object'])

# %%
y = numeric_data['overall']

# %%
n_nm = non_numeric['preferred_foot']

# %%
n_nm, values = pd.factorize(n_nm)

# %%
n_nm = pd.get_dummies(n_nm).astype(int)

# %%
n_nm.columns = ['Left', 'Right']

# %%
x = pd.concat([numeric_data, n_nm], axis=1)

# %%
x = pd.DataFrame(x, columns=x.columns)

# %%
x.fillna(x.mean(), inplace=True)

# %% [markdown]
# Correlation Analysis

# %%
correlation = x.corr()

# %%
correlation
# Out:
#                               overall  potential  value_eur  wage_eur  \
# overall                      1.000000   0.695362   0.563962  0.608711
# potential                    0.695362   1.000000   0.530834  0.508817
# value_eur                    0.563962   0.530834   1.000000  0.777742
# wage_eur                     0.608711   0.508817   0.777742  1.000000
# age                          0.458390  -0.201506   0.068778  0.166780
# height_cm                    0.044415   0.006744   0.010512  0.023949
# weight_kg                    0.140015  -0.008111   0.035567  0.064959
# league_level                -0.220234  -0.192086  -0.132355 -0.152585
# club_team_id                -0.177489  -0.261007  -0.163703 -0.208040
# club_jersey_number          -0.186287  -0.003827  -0.066066 -0.075480
# nationality_id              -0.093951  -0.167749  -0.065182 -0.071816
# weak_foot                    0.217422   0.167492   0.147011  0.149526
# skill_moves                  0.330951   0.285126   0.250674  0.234718
# international_reputation     0.485234   0.367256   0.599251  0.677305
# release_clause_eur           0.461829   0.439297   0.896439  0.631423
# pace                         0.173856   0.246502   0.164640  0.138985
# shooting                     0.448143   0.297238   0.289034  0.307049
# passing                      0.632617   0.426834   0.379065  0.407007
# dribbling                    0.563384   0.456270   0.368573  0.374815
# defending                    0.301999   0.148881   0.124684  0.157404
# physic                       0.476732   0.173304   0.199651  0.243555
# attacking_crossing           0.396833   0.264256   0.224409  0.252064
# attacking_finishing          0.326376   0.245701   0.222716  0.229218
# attacking_heading_accuracy   0.340029   0.208889   0.163513  0.208922
# attacking_short_passing      0.499757   0.383164   0.293257  0.312878
# attacking_volleys            0.377048   0.256491   0.244868  0.272165
# skill_dribbling              0.369827   0.324038   0.240764  0.247400
# skill_curve                  0.415863   0.292871   0.254026  0.277490
# skill_fk_accuracy            0.387269   0.235827   0.221891  0.254166
# skill_long_passing           0.483808   0.341345   0.274443  0.299891
# skill_ball_control           0.457011   0.366798   0.271870  0.291152
# movement_acceleration        0.194625   0.240387   0.153569  0.140469
# movement_sprint_speed        0.208990   0.244990   0.157883  0.147947
# movement_agility             0.263671   0.235361   0.173709  0.168530
# movement_reactions           0.845753   0.540548   0.487550  0.533264
# movement_balance             0.099129   0.131958   0.103188  0.087428
# power_shot_power             0.480297   0.326665   0.269300  0.296703
# power_jumping                0.275578   0.129966   0.119053  0.154998
# power_stamina                0.360025   0.212416   0.188766  0.199225
# power_strength               0.350786   0.099452   0.124345  0.162576
# power_long_shots             0.409086   0.270333   0.238360  0.265984
# mentality_aggression         0.398310   0.197977   0.172438  0.219275
# mentality_interceptions      0.314282   0.163596   0.132821  0.170492
# mentality_positioning        0.350178   0.253592   0.228446  0.240221
# mentality_vision             0.493282   0.358591   0.317922  0.325700
# mentality_penalties          0.334488   0.225312   0.201472  0.240260
# mentality_composure          0.604074   0.370952   0.379144  0.354989
# defending_marking_awareness  0.274173   0.152613   0.116048  0.135792
# defending_standing_tackle    0.250624   0.152078   0.107322  0.137312
# defending_sliding_tackle     0.220398   0.134847   0.089100  0.120443
# goalkeeping_diving          -0.013603  -0.044826  -0.016602 -0.020030
# goalkeeping_handling        -0.010862  -0.044119  -0.015640 -0.019914
# goalkeeping_kicking         -0.015521  -0.048803  -0.017033 -0.021678
# goalkeeping_positioning     -0.004731  -0.042978  -0.015133 -0.018547
# goalkeeping_reflexes        -0.011783  -0.044156  -0.015483 -0.020112
# Left                         0.042408   0.035255   0.015103  0.011884
# Right                       -0.042408  -0.035255  -0.015103 -0.011884
#
#                                   age  height_cm  weight_kg  league_level  \
# overall                      0.458390   0.044415   0.140015     -0.220234
# potential                   -0.201506   0.006744  -0.008111     -0.192086
# value_eur                    0.068778   0.010512   0.035567     -0.132355
# wage_eur                     0.166780   0.023949   0.064959     -0.152585
# age                          1.000000   0.081498   0.226143     -0.059423
# height_cm                    0.081498   1.000000   0.764081      0.055312
# weight_kg                    0.226143   0.764081   1.000000      0.008707
# league_level                -0.059423   0.055312   0.008707      1.000000
# club_team_id                 0.079818  -0.113225  -0.056664     -0.156491
# club_jersey_number          -0.222049  -0.031432  -0.073194     -0.091508
# nationality_id               0.059412  -0.132742  -0.111379     -0.253443
# weak_foot                    0.076077  -0.169790  -0.130435     -0.020446
# skill_moves                  0.030409  -0.422632  -0.357432     -0.067582
# international_reputation     0.254862   0.041569   0.088131     -0.112240
# release_clause_eur           0.039268   0.006333   0.027368     -0.108784
# pace                        -0.182854  -0.369168  -0.328289     -0.015211
# shooting                     0.214590  -0.171986  -0.085015     -0.102536
# passing                      0.305078  -0.244968  -0.161077     -0.161010
# dribbling                    0.150606  -0.352552  -0.264088     -0.144684
# defending                    0.232745   0.193898   0.187520     -0.072635
# physic                       0.392617   0.442289   0.512329     -0.035770
# attacking_crossing           0.132147  -0.480842  -0.394579     -0.079478
# attacking_finishing          0.074307  -0.359129  -0.285231     -0.055175
# attacking_heading_accuracy   0.149113   0.016406   0.037275     -0.056640
# attacking_short_passing      0.138069  -0.354358  -0.288999     -0.111988
# attacking_volleys            0.137191  -0.340105  -0.258681     -0.076919
# skill_dribbling              0.015545  -0.486293  -0.413044     -0.078567
# skill_curve                  0.142872  -0.432668  -0.347436     -0.083807
# skill_fk_accuracy            0.190229  -0.393450  -0.303106     -0.072037
# skill_long_passing           0.184407  -0.321426  -0.259153     -0.109992
# skill_ball_control           0.088184  -0.408172  -0.337844     -0.091995
# movement_acceleration       -0.159198  -0.540692  -0.480990     -0.004999
# movement_sprint_speed       -0.150952  -0.458293  -0.409278     -0.006321
# movement_agility            -0.020493  -0.620438  -0.539978     -0.015528
# movement_reactions           0.450263  -0.005868   0.086777     -0.195936
# movement_balance            -0.087013  -0.789537  -0.673200     -0.007572
# power_shot_power             0.200711  -0.226775  -0.136138     -0.099176
# power_jumping                0.184829  -0.039473   0.026379     -0.007245
# power_stamina                0.102691  -0.284735  -0.226385     -0.009917
# power_strength               0.333180   0.539854   0.614735     -0.015376
# power_long_shots             0.154491  -0.373037  -0.278904     -0.080461
# mentality_aggression         0.259104  -0.046698   0.018354     -0.059723
# mentality_interceptions      0.192084  -0.052398  -0.033365     -0.060989
# mentality_positioning        0.085707  -0.428944  -0.347337     -0.071178
# mentality_vision             0.190345  -0.365754  -0.289970     -0.107503
# mentality_penalties          0.135014  -0.326687  -0.244227     -0.058530
# mentality_composure          0.322023  -0.146071  -0.064273     -0.105145
# defending_marking_awareness  0.153170  -0.053724  -0.039288     -0.053215
# defending_standing_tackle    0.117334  -0.059223  -0.051595     -0.045703
# defending_sliding_tackle     0.099728  -0.069303  -0.063314     -0.045949
# goalkeeping_diving           0.105135   0.361519   0.340277     -0.016009
# goalkeeping_handling         0.110222   0.361193   0.339970     -0.015793
# goalkeeping_kicking          0.108064   0.358273   0.337763     -0.019038
# goalkeeping_positioning      0.118871   0.360780   0.341659     -0.018956
# goalkeeping_reflexes         0.106004   0.361376   0.340076     -0.016535
# Left                         0.000866  -0.077713  -0.074001      0.001991
# Right                       -0.000866   0.077713   0.074001     -0.001991
#
#                              club_team_id  club_jersey_number  ...  \
# overall                         -0.177489           -0.186287  ...
# potential                       -0.261007           -0.003827  ...
# value_eur                       -0.163703           -0.066066  ...
# wage_eur                        -0.208040           -0.075480  ...
# age                              0.079818           -0.222049  ...
# height_cm                       -0.113225           -0.031432  ...
# weight_kg                       -0.056664           -0.073194  ...
# league_level                    -0.156491           -0.091508  ...
# club_team_id                     1.000000            0.014789  ...
# club_jersey_number               0.014789            1.000000  ...
# nationality_id                   0.266143            0.027014  ...
# weak_foot                       -0.067605           -0.033795  ...
# skill_moves                     -0.057906           -0.018530  ...
# international_reputation        -0.141444           -0.058094  ...
# release_clause_eur              -0.150421           -0.057527  ...
# pace                            -0.056913            0.023486  ...
# shooting                        -0.088488           -0.012265  ...
# passing                         -0.123004           -0.093695  ...
# dribbling                       -0.123198           -0.033274  ...
# defending                       -0.056121           -0.134404  ...
# physic                          -0.075572           -0.179562  ...
# attacking_crossing              -0.068296           -0.064661  ...
# attacking_finishing             -0.058794           -0.008792  ...
# attacking_heading_accuracy      -0.051710           -0.083939  ...
# attacking_short_passing         -0.087372           -0.088161  ...
# attacking_volleys               -0.078399           -0.020766  ...
# skill_dribbling                 -0.075617           -0.022944  ...
# skill_curve                     -0.090812           -0.048327  ...
# skill_fk_accuracy               -0.062900           -0.060665  ...
# skill_long_passing              -0.084258           -0.101472  ...
# skill_ball_control              -0.090744           -0.063823  ...
# movement_acceleration           -0.049129           -0.003462  ...
# movement_sprint_speed           -0.053210           -0.011350  ...
# movement_agility                -0.049893           -0.028967  ...
# movement_reactions              -0.143692           -0.165077  ...
# movement_balance                -0.011091            0.007363  ...
# power_shot_power                -0.094155           -0.047225  ...
# power_jumping                   -0.047611           -0.105131  ...
# power_stamina                   -0.046398           -0.117125  ...
# power_strength                  -0.050683           -0.144408  ...
# power_long_shots                -0.067630           -0.037910  ...
# mentality_aggression            -0.075366           -0.127035  ...
# mentality_interceptions         -0.050570           -0.134037  ...
# mentality_positioning           -0.057994           -0.024093  ...
# mentality_vision                -0.099304           -0.065628  ...
# mentality_penalties             -0.052607           -0.023968  ...
# mentality_composure             -0.134574           -0.120990  ...
# defending_marking_awareness     -0.042389           -0.122628  ...
# defending_standing_tackle       -0.046079           -0.111443  ...
# defending_sliding_tackle        -0.039457           -0.102225  ...
# goalkeeping_diving              -0.005627            0.004104  ...
# goalkeeping_handling            -0.005712            0.001212  ...
# goalkeeping_kicking             -0.004205            0.001885  ...
# goalkeeping_positioning         -0.005055           -0.001096  ...
# goalkeeping_reflexes            -0.005971            0.002949  ...
# Left                            -0.019023           -0.010923  ...
# Right                            0.019023            0.010923  ...
#
#                              defending_marking_awareness  \
# overall                                         0.274173
# potential                                       0.152613
# value_eur                                       0.116048
# wage_eur                                        0.135792
# age                                             0.153170
# height_cm                                      -0.053724
# weight_kg                                      -0.039288
# league_level                                   -0.053215
# club_team_id                                   -0.042389
# club_jersey_number                             -0.122628
# nationality_id                                 -0.021351
# weak_foot                                       0.044076
# skill_moves                                     0.143183
# international_reputation                        0.096148
# release_clause_eur                              0.106740
# pace                                           -0.228196
# shooting                                       -0.360859
# passing                                         0.102441
# dribbling                                      -0.157395
# defending                                       0.812535
# physic                                          0.421461
# attacking_crossing                              0.413271
# attacking_finishing                            -0.032111
# attacking_heading_accuracy                      0.561950
# attacking_short_passing                         0.524307
# attacking_volleys                               0.059323
# skill_dribbling                                 0.285043
# skill_curve                                     0.251347
# skill_fk_accuracy                               0.259591
# skill_long_passing                              0.567682
# skill_ball_control                              0.408891
# movement_acceleration                           0.162798
# movement_sprint_speed                           0.184973
# movement_agility                                0.131683
# movement_reactions                              0.270564
# movement_balance                                0.150406
# power_shot_power                                0.155531
# power_jumping                                   0.283793
# power_stamina                                   0.565324
# power_strength                                  0.334305
# power_long_shots                                0.161095
# mentality_aggression                            0.724533
# mentality_interceptions                         0.915789
# mentality_positioning                           0.147884
# mentality_vision                                0.154004
# mentality_penalties                             0.103827
# mentality_composure                             0.367387
# defending_marking_awareness                     1.000000
# defending_standing_tackle                       0.938874
# defending_sliding_tackle                        0.933424
# goalkeeping_diving                             -0.512379
# goalkeeping_handling                           -0.512966
# goalkeeping_kicking                            -0.511830
# goalkeeping_positioning                        -0.509178
# goalkeeping_reflexes                           -0.513083
# Left                                            0.105188
# Right                                          -0.105188
#
#                              defending_standing_tackle  \
# overall                                       0.250624
# potential                                     0.152078
# value_eur                                     0.107322
# wage_eur                                      0.137312
# age                                           0.117334
# height_cm                                    -0.059223
# weight_kg                                    -0.051595
# league_level                                 -0.045703
# club_team_id                                 -0.046079
# club_jersey_number                           -0.111443
# nationality_id                               -0.025782
# weak_foot                                     0.037699
# skill_moves                                   0.144599
# international_reputation                      0.093740
# release_clause_eur                            0.096651
# pace                                         -0.233182
# shooting                                     -0.374866
# passing                                       0.105917
# dribbling                                    -0.164161
# defending                                     0.821146
# physic                                        0.414890
# attacking_crossing                            0.419214
# attacking_finishing                          -0.042165
# attacking_heading_accuracy                    0.553583
# attacking_short_passing                       0.529947
# attacking_volleys                             0.053555
# skill_dribbling                               0.287615
# skill_curve                                   0.254198
# skill_fk_accuracy                             0.268098
# skill_long_passing                            0.578031
# skill_ball_control                            0.408005
# movement_acceleration                         0.161437
# movement_sprint_speed                         0.181804
# movement_agility                              0.125949
# movement_reactions                            0.249997
# movement_balance                              0.152846
# power_shot_power                              0.148834
# power_jumping                                 0.268473
# power_stamina                                 0.566490
# power_strength                                0.321256
# power_long_shots                              0.158911
# mentality_aggression                          0.736647
# mentality_interceptions                       0.939171
# mentality_positioning                         0.146299
# mentality_vision                              0.154959
# mentality_penalties                           0.097027
# mentality_composure                           0.344716
# defending_marking_awareness                   0.938874
# defending_standing_tackle                     1.000000
# defending_sliding_tackle                      0.973618
# goalkeeping_diving                           -0.522018
# goalkeeping_handling                         -0.522194
# goalkeeping_kicking                          -0.521826
# goalkeeping_positioning                      -0.519435
# goalkeeping_reflexes                         -0.522991
# Left                                          0.108856
# Right                                        -0.108856
#
#                              defending_sliding_tackle  goalkeeping_diving  \
# overall                                      0.220398           -0.013603
# potential                                    0.134847           -0.044826
# value_eur                                    0.089100           -0.016602
# wage_eur                                     0.120443           -0.020030
# age                                          0.099728            0.105135
# height_cm                                   -0.069303            0.361519
# weight_kg                                   -0.063314            0.340277
# league_level                                -0.045949           -0.016009
# club_team_id                                -0.039457           -0.005627
# club_jersey_number                          -0.102225            0.004104
# nationality_id                              -0.027100           -0.020760
# weak_foot                                    0.020391           -0.228172
# skill_moves                                  0.113840           -0.609174
# international_reputation                     0.080184            0.007831
# release_clause_eur                           0.081244           -0.017743
# pace                                        -0.221005           -0.001444
# shooting                                    -0.408282            0.002899
# passing                                      0.083481            0.004067
# dribbling                                   -0.181320            0.001771
# defending                                    0.820915            0.003813
# physic                                       0.389603            0.006318
# attacking_crossing                           0.402622           -0.655014
# attacking_finishing                         -0.080297           -0.576174
# attacking_heading_accuracy                   0.526271           -0.739182
# attacking_short_passing                      0.497037           -0.721705
# attacking_volleys                            0.017577           -0.576750
# skill_dribbling                              0.261560           -0.744364
# skill_curve                                  0.225650           -0.599407
# skill_fk_accuracy                            0.236745           -0.549578
# skill_long_passing                           0.552861           -0.591420
# skill_ball_control                           0.375205           -0.783591
# movement_acceleration                        0.157338           -0.589651
# movement_sprint_speed                        0.176996           -0.595856
# movement_agility                             0.115361           -0.523677
# movement_reactions                           0.221740           -0.053871
# movement_balance                             0.153266           -0.497854
# power_shot_power                             0.114272           -0.492783
# power_jumping                                0.268358           -0.180177
# power_stamina                                0.541659           -0.692611
# power_strength                               0.292499           -0.099464
# power_long_shots                             0.120891           -0.598947
# mentality_aggression                         0.714566           -0.573934
# mentality_interceptions                      0.925751           -0.480984
# mentality_positioning                        0.113332           -0.668160
# mentality_vision                             0.120445           -0.405722
# mentality_penalties                          0.062479           -0.614186
# mentality_composure                          0.312580           -0.401539
# defending_marking_awareness                  0.933424           -0.512379
# defending_standing_tackle                    0.973618           -0.522018
# defending_sliding_tackle                     1.000000           -0.501445
# goalkeeping_diving                          -0.501445            1.000000
# goalkeeping_handling                        -0.501706            0.969490
# goalkeeping_kicking                         -0.501221            0.965409
# goalkeeping_positioning                     -0.498695            0.969202
# goalkeeping_reflexes                        -0.502051            0.973063
# Left                                         0.116293           -0.101676
# Right                                       -0.116293            0.101676
#
#                              goalkeeping_handling  goalkeeping_kicking  \
# overall                                 -0.010862            -0.015521
# potential                               -0.044119            -0.048803
# value_eur                               -0.015640            -0.017033
# wage_eur                                -0.019914            -0.021678
# age                                      0.110222             0.108064
# height_cm                                0.361193             0.358273
# weight_kg                                0.339970             0.337763
# league_level                            -0.015793            -0.019038
# club_team_id                            -0.005712            -0.004205
# club_jersey_number                       0.001212             0.001885
# nationality_id                          -0.022670            -0.019476
# weak_foot                               -0.227125            -0.223385
# skill_moves                             -0.606615            -0.604504
# international_reputation                 0.008328             0.006148
# release_clause_eur                      -0.017415            -0.018357
# pace                                    -0.000484             0.000034
# shooting                                 0.004417             0.006571
# passing                                  0.005945             0.005762
# dribbling                                0.003215             0.004110
# defending                                0.002723             0.002231
# physic                                   0.006613             0.006654
# attacking_crossing                      -0.653081            -0.652080
# attacking_finishing                     -0.574394            -0.571625
# attacking_heading_accuracy              -0.738239            -0.735015
# attacking_short_passing                 -0.719376            -0.716196
# attacking_volleys                       -0.574831            -0.572201
# skill_dribbling                         -0.742579            -0.739953
# skill_curve                             -0.596953            -0.594959
# skill_fk_accuracy                       -0.547138            -0.544646
# skill_long_passing                      -0.588648            -0.585432
# skill_ball_control                      -0.781466            -0.778400
# movement_acceleration                   -0.590718            -0.588336
# movement_sprint_speed                   -0.596899            -0.594351
# movement_agility                        -0.523508            -0.522421
# movement_reactions                      -0.052654            -0.055949
# movement_balance                        -0.498914            -0.495968
# power_shot_power                        -0.489649            -0.483835
# power_jumping                           -0.180855            -0.181760
# power_stamina                           -0.690993            -0.688667
# power_strength                          -0.098623            -0.099864
# power_long_shots                        -0.597173            -0.593730
# mentality_aggression                    -0.572595            -0.570991
# mentality_interceptions                 -0.481032            -0.480304
# mentality_positioning                   -0.666046            -0.662973
# mentality_vision                        -0.399873            -0.397474
# mentality_penalties                     -0.612530            -0.608465
# mentality_composure                     -0.400091            -0.400402
# defending_marking_awareness             -0.512966            -0.511830
# defending_standing_tackle               -0.522194            -0.521826
# defending_sliding_tackle                -0.501706            -0.501221
# goalkeeping_diving                       0.969490             0.965409
# goalkeeping_handling                     1.000000             0.964983
# goalkeeping_kicking                      0.964983             1.000000
# goalkeeping_positioning                  0.968882             0.964387
# goalkeeping_reflexes                     0.969626             0.965943
# Left                                    -0.101548            -0.103994
# Right                                    0.101548             0.103994
#
#                              goalkeeping_positioning  goalkeeping_reflexes  \
# overall                                    -0.004731             -0.011783
# potential                                  -0.042978             -0.044156
# value_eur                                  -0.015133             -0.015483
# wage_eur                                   -0.018547             -0.020112
# age                                         0.118871              0.106004
# height_cm                                   0.360780              0.361376
# weight_kg                                   0.341659              0.340076
# league_level                               -0.018956             -0.016535
# club_team_id                               -0.005055             -0.005971
# club_jersey_number                         -0.001096              0.002949
# nationality_id                             -0.021114             -0.023196
# weak_foot                                  -0.225471             -0.228998
# skill_moves                                -0.605512             -0.608444
# international_reputation                    0.010632              0.007910
# release_clause_eur                         -0.016513             -0.016606
# pace                                       -0.003350             -0.001375
# shooting                                    0.003315              0.004563
# passing                                     0.004269              0.004584
# dribbling                                   0.001642              0.002441
# defending                                   0.004373              0.002479
# physic                                      0.007422              0.005752
# attacking_crossing                         -0.652616             -0.654719
# attacking_finishing                        -0.573359             -0.574306
# attacking_heading_accuracy                 -0.734845             -0.738721
# attacking_short_passing                    -0.716887             -0.720835
# attacking_volleys                          -0.573561             -0.574824
# skill_dribbling                            -0.741020             -0.743264
# skill_curve                                -0.597145             -0.598034
# skill_fk_accuracy                          -0.547167             -0.548247
# skill_long_passing                         -0.586624             -0.590499
# skill_ball_control                         -0.778972             -0.782679
# movement_acceleration                      -0.588470             -0.589029
# movement_sprint_speed                      -0.594652             -0.595258
# movement_agility                           -0.521814             -0.523413
# movement_reactions                         -0.046384             -0.051144
# movement_balance                           -0.496598             -0.497556
# power_shot_power                           -0.487707             -0.491919
# power_jumping                              -0.177388             -0.180045
# power_stamina                              -0.688293             -0.692049
# power_strength                             -0.094813             -0.099243
# power_long_shots                           -0.594894             -0.596839
# mentality_aggression                       -0.569089             -0.573839
# mentality_interceptions                    -0.477618             -0.481581
# mentality_positioning                      -0.664363             -0.666305
# mentality_vision                           -0.398383             -0.403801
# mentality_penalties                        -0.611202             -0.613117
# mentality_composure                        -0.395587             -0.399208
# defending_marking_awareness                -0.509178             -0.513083
# defending_standing_tackle                  -0.519435             -0.522991
# defending_sliding_tackle                   -0.498695             -0.502051
# goalkeeping_diving                          0.969202              0.973063
# goalkeeping_handling                        0.968882              0.969626
# goalkeeping_kicking                         0.964387              0.965943
# goalkeeping_positioning                     1.000000              0.969506
# goalkeeping_reflexes                        0.969506              1.000000
# Left                                       -0.102723             -0.101531
# Right                                       0.102723              0.101531
#
#                                  Left     Right
# overall                      0.042408 -0.042408
# potential                    0.035255 -0.035255
# value_eur                    0.015103 -0.015103
# wage_eur                     0.011884 -0.011884
# age                          0.000866 -0.000866
# height_cm                   -0.077713  0.077713
# weight_kg                   -0.074001  0.074001
# league_level                 0.001991 -0.001991
# club_team_id                -0.019023  0.019023
# club_jersey_number          -0.010923  0.010923
# nationality_id              -0.029125  0.029125
# weak_foot                   -0.077052  0.077052
# skill_moves                  0.095607 -0.095607
# international_reputation     0.000510 -0.000510
# release_clause_eur           0.013637 -0.013637
# pace                         0.063653 -0.063653
# shooting                    -0.022281  0.022281
# passing                      0.079976 -0.079976
# dribbling                    0.059078 -0.059078
# defending                    0.054001 -0.054001
# physic                      -0.036395  0.036395
# attacking_crossing           0.202245 -0.202245
# attacking_finishing          0.032041 -0.032041
# attacking_heading_accuracy   0.038817 -0.038817
# attacking_short_passing      0.095663 -0.095663
# attacking_volleys            0.045047 -0.045047
# skill_dribbling              0.125516 -0.125516
# skill_curve                  0.152508 -0.152508
# skill_fk_accuracy            0.143166 -0.143166
# skill_long_passing           0.103123 -0.103123
# skill_ball_control           0.109518 -0.109518
# movement_acceleration        0.116307 -0.116307
# movement_sprint_speed        0.113587 -0.113587
# movement_agility             0.103109 -0.103109
# movement_reactions           0.019882 -0.019882
# movement_balance             0.089408 -0.089408
# power_shot_power             0.052201 -0.052201
# power_jumping               -0.024758  0.024758
# power_stamina                0.090244 -0.090244
# power_strength              -0.035770  0.035770
# power_long_shots             0.074737 -0.074737
# mentality_aggression         0.056008 -0.056008
# mentality_interceptions      0.098774 -0.098774
# mentality_positioning        0.085586 -0.085586
# mentality_vision             0.060884 -0.060884
# mentality_penalties          0.052131 -0.052131
# mentality_composure          0.050676 -0.050676
# defending_marking_awareness  0.105188 -0.105188
# defending_standing_tackle    0.108856 -0.108856
# defending_sliding_tackle     0.116293 -0.116293
# goalkeeping_diving          -0.101676  0.101676
# goalkeeping_handling        -0.101548  0.101548
# goalkeeping_kicking         -0.103994  0.103994
# goalkeeping_positioning     -0.102723  0.102723
# goalkeeping_reflexes        -0.101531  0.101531
# Left                         1.000000 -1.000000
# Right                       -1.000000  1.000000
#
# [57 rows x 57 columns]

# %%
correlation_target = correlation['overall']
selected_features = correlation_target[correlation_target.abs() > 0.4].index

x = x[selected_features]

# %%
x.drop('overall', axis=1, inplace=True)

# %% [markdown]
# Model Training with Cross-Validation

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x = scaler.fit_transform(x)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
nb = GaussianNB()
sv = SVC(probability=True)
rf = RandomForestClassifier(n_estimators=100, random_state=42)
gb = GradientBoostingClassifier(n_estimators=100, random_state=42)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
import pickle as pkl

# %%
for model in (nb, sv, rf, gb):
    model.fit(xtrain, ytrain)
    pkl.dump(model, open('C:\\Users\\User\\OneDrive - Ashesi University\\Desktop\\Introduction to AI\\Jupyter Codes'  + model.__class__.__name__ + '.pkl', 'wb'))
    y_pred = model.predict(xtest)
    scorer = make_scorer(mean_absolute_error, greater_is_better=False)
    print(model.__class__.__name__, cross_val_score(model, xtrain, ytrain, cv=2, scoring=scorer))
# Out:
# SVC [1.29645584 1.30403567]
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression [1.86600306 1.86094253]
# RandomForestClassifier [0.98662006 0.996862  ]

# %% [markdown]
# Model Evaluation and Optimization

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30]
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42), parameters, cv=5, scoring=scorer)
grid_search.fit(xtrain, ytrain)

print(f'Best parameters: {grid_search.best_params_}')
print(f'Best CV MAE: {-grid_search.best_score_}')

best_model = grid_search.best_estimator_

# Evaluate on validation set
y_pred = best_model.predict(xtest)
mae = mean_absolute_error(ytest, y_pred)
print(f'Validation MAE: {mae}')

# %% [markdown]
# Testing on a Different Dataset

# %%
xtest = players.drop('overall', axis=1)
ytest = players['overall']

y_test_pred = best_model.predict(xtest)
test_mae =mean_absolute_error(ytest, y_test_pred)
print(f'Test MAE: {test_mae}')

# %% [markdown]
# Deploying the Model on a Web Page

# %%
from flask import Flask, request, jsonify
import joblib

app = Flask(__name__)

# Load the trained model
model = joblib.load('best_model.pkl')

@app.route('/predict', methods=['POST'])
def predict():
    data = request.json
    input_data = pd.DataFrame([data])  
    
    # Predict using the loaded model
    prediction = model.predict(input_data)
    
    response = {
        'rating': prediction[0],
        'confidence': 0.95  
    }
    
    return jsonify(response)

if __name__ == '__main__':
    app.run(debug=True)
